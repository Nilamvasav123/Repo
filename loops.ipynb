# %%
'''- print squares of numbers from 1 to 5
- Find sum of numbers from 1 to 10 
- Count how many numbers between 1 to 50 are divisible by 7 '''


#1.

for i in range(1, 6): 
    print(f"{i} squared is {i**2}")
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9
# 4 squared is 16
# 5 squared is 25

# %%
#Find sum of numbers from 1 to 10

total= sum(range(1, 11))
print("enter sum of 1 to 10 numbers :",total)
# Out:
# enter sum of 1 to 10 numbers : 55

# %%
#Count how many numbers between 1 to 50 are divisible by 7
for i in range(1, 51):
    if i%7==0:
        print(f"this number divisible 7",{i})
# Out:
# this number divisible 7 {7}
# this number divisible 7 {14}
# this number divisible 7 {21}
# this number divisible 7 {28}
# this number divisible 7 {35}
# this number divisible 7 {42}
# this number divisible 7 {49}

# %% [markdown]
# # Interview
#
# 1. Print mutiliplication table of 5
#     5 * 1=5
#     5 * 2=10
#
# 2. Reverse loop: Print 10 to 1
#
# 3. Find first number divisble by 9 between 1 to 100
#
# 4. for i in range(1,10,3)
#     print(i)
# 5.  for i in range(5,5)
#     print(i)
#
# 7. Print numbers 1 to 100 with rules
#     - divisble by 3 - FIZZ
#     - divisble by 5 - BUZZ
#     - divisble by 7 - JAZZ
#
#     - if divible by multiple,concatenate(105- FIZZBUZZJAZZ)
#     - Print the number

# %%
'''# Interview 

1. Print mutiliplication table of 5 
    5 * 1=5 
    5 * 2=10'''

for i in range(1, 51):
    if i%5==0:
            print(f"this is multiplication by 5 =",{i})
# Out:
# this is multiplication by 5 = {5}
# this is multiplication by 5 = {10}
# this is multiplication by 5 = {15}
# this is multiplication by 5 = {20}
# this is multiplication by 5 = {25}
# this is multiplication by 5 = {30}
# this is multiplication by 5 = {35}
# this is multiplication by 5 = {40}
# this is multiplication by 5 = {45}
# this is multiplication by 5 = {50}

# %%
#2. Reverse loop: Print 10 to 1
 for ch in range(1,11)
# Out:
#   Cell In[15], line 2
#     for ch in range(1,11)
#     ^
# IndentationError: unexpected indent

# %%
#2. Reverse loop: Print 10 to 1

for ch in range(10,0,-1) :
    print(f"print reverce loop :{ch}")
# Out:
# print reverce loop :10
# print reverce loop :9
# print reverce loop :8
# print reverce loop :7
# print reverce loop :6
# print reverce loop :5
# print reverce loop :4
# print reverce loop :3
# print reverce loop :2
# print reverce loop :1

# %%
#3. Find first number divisble by 9 between 1 to 100
for ch in range(1,101) :
    if ch%9==0:
        print(f"this number divisble by 9 :{ch}")
# Out:
# this number divisble by 9 :9
# this number divisble by 9 :18
# this number divisble by 9 :27
# this number divisble by 9 :36
# this number divisble by 9 :45
# this number divisble by 9 :54
# this number divisble by 9 :63
# this number divisble by 9 :72
# this number divisble by 9 :81
# this number divisble by 9 :90
# this number divisble by 9 :99

# %%
#4. for i in range(1,10,3) then  print(i)
for i in range  (1,10,3):
      print(i)
# Out:
# 1
# 4
# 7

# %%
#5.  for i in range(5,5)
   # print(i)
for i in range (5,5):
   print(i)

# %%
'''7. Print numbers 1 to 100 with rules 
    - divisble by 3 - FIZZ
    - divisble by 5 - BUZZ
    - divisble by 7 - JAZZ 

    - if divible by multiple,concatenate(105- FIZZBUZZJAZZ)
    - Print the number '''

for num in range(1,101):
    if num%3==0 :
        print(f"this is fizz: {num}")
    elif num%5==0 :
        print(f"this is buzz :{num}")
    elif num%7==0 :
        print(f"this is jazz :{num}")

       
    else:
        print("this is not fizz")
# Out:
# this is not fizz
# this is not fizz
# this is fizz: 3
# this is not fizz
# this is buzz :5
# this is fizz: 6
# this is jazz :7
# this is not fizz
# this is fizz: 9
# this is buzz :10
# this is not fizz
# this is fizz: 12
# this is not fizz
# this is jazz :14
# this is fizz: 15
# this is not fizz
# this is not fizz
# this is fizz: 18
# this is not fizz
# this is buzz :20
# this is fizz: 21
# this is not fizz
# this is not fizz
# this is fizz: 24
# this is buzz :25
# this is not fizz
# this is fizz: 27
# this is jazz :28
# this is not fizz
# this is fizz: 30
# this is not fizz
# this is not fizz
# this is fizz: 33
# this is not fizz
# this is buzz :35
# this is fizz: 36
# this is not fizz
# this is not fizz
# this is fizz: 39
# this is buzz :40
# this is not fizz
# this is fizz: 42
# this is not fizz
# this is not fizz
# this is fizz: 45
# this is not fizz
# this is not fizz
# this is fizz: 48
# this is jazz :49
# this is buzz :50
# this is fizz: 51
# this is not fizz
# this is not fizz
# this is fizz: 54
# this is buzz :55
# this is jazz :56
# this is fizz: 57
# this is not fizz
# this is not fizz
# this is fizz: 60
# this is not fizz
# this is not fizz
# this is fizz: 63
# this is not fizz
# this is buzz :65
# this is fizz: 66
# this is not fizz
# this is not fizz
# this is fizz: 69
# this is buzz :70
# this is not fizz
# this is fizz: 72
# this is not fizz
# this is not fizz
# this is fizz: 75
# this is not fizz
# this is jazz :77
# this is fizz: 78
# this is not fizz
# this is buzz :80
# this is fizz: 81
# this is not fizz
# this is not fizz
# this is fizz: 84
# this is buzz :85
# this is not fizz
# this is fizz: 87
# this is not fizz
# this is not fizz
# this is fizz: 90
# this is jazz :91
# this is not fizz
# this is fizz: 93
# this is not fizz
# this is buzz :95
# this is fizz: 96
# this is not fizz
# this is jazz :98
# this is fizz: 99
# this is buzz :100
