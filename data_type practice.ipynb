# %%
## Questions-----

##1. s="python"

  #  extract:
  #   First 3 charcters 
  #  last 2 charcters 
  #  Remove first charcter 

s="python"
print(s[:3])
# Out:
# pyt

# %%
s="python"
print(s[4:])
# Out:
# on

# %%
s="python"
print(s[1:])
# Out:
# ython

# %%
#2. s= "developer"
 #extract:
 # - "deve"
 #- "lop"
 #- Everything except last charcter

# %%
s="developer"
print(s[-9:-1])
print(s[-9:8])
# Out:
# develope
# develope

# %%
s="developer"
print(s[:4])
# Out:
# deve

# %%
s="developer"
print(s[-5:7:])
# Out:
# lop

# %%
#3. s= "datascience"
   # extarct:
    #    - middle part "scien"
     #   - first half only 
      #  - last half only

# %%
s= "datascience"
print(s[4:-2])
print(s[4:9])
# Out:
# scien
# scien

# %%
s= "datascience"
print(s[:5])
# Out:
# datas

# %%
s= "datascience"
print(s[5:])
# Out:
# cience

# %%
#4. s= "abcdef"
   # extarct:
      #  - Every alternate charcter 
      #  - Characters at odd position 

s= "abcdef"
print(s[:6:2])
# Out:
# ace

# %%
s= "abcdef"
print(s[1:6:2])
# Out:
# bdf

# %%
#5. filename="care_delta_income_sepetember_2024.xlsx"

   # extarct:
       # - File extension 
      #  - File name without extension 
       # - Year only
filename="care_delta_income_sepetember_2024.xlsx"
print(filename[-5:])
# Out:
# .xlsx

# %%
filename="care_delta_income_sepetember_2024.xlsx"
print(filename[:-5])
# Out:
# care_delta_income_sepetember_2024

# %%
filename="care_delta_income_sepetember_2024.xlsx"
print(filename[-9:-5])
# Out:
# 2024

# %%
#6. log="[INFO] job completed sucessfully [END]"
   # extarct:
     #   - job completed sucessfully

log="[INFO] job completed sucessfully [END]"
print(log[6:-6])
# Out:
#  job completed sucessfully

# %%
#7. s="machinelearning"
 #   extarct: 
  #      - Reverse full string 
   #     - Reverse only "learning"
    #    - Reverse string except first charcter
s="machinelearning"
print(s[-1::-1])
# Out:
# gninraelenihcam

# %%
s="machinelearning"
p=s[-8::]
print(p[::-1])
# Out:
# gninrael

# %%
s="machinelearning"
q=s[0]+s[1:][::-1]
print(q)
# Out:
# mgninraelenihca

# %%
#8. s="ABCDEFGHIJKLMNO"
 #   extarct:
       # - Charcters from index 3 to 12 skipping 2 
       # - Reverse slice from index 10 to 3 

s="ABCDEFGHIJKLMNO"
p=(s[3:13][::-2])
print(p[::-1])
# Out:
# EGIKM

# %%
s="ABCDEFGHIJKLMNO"
#p=(s[3:10])
print(s[3:10][::-1])
# Out:
# JIHGFED

# %%
#9. path="/mnt/data/input/care_delta_income_2024.csv"
 #   extarct:
  #      - File Name 
   #     - File name without extension 
    #    - Extension 

path="/mnt/data/input/care_delta_income_2024.csv"
print(path[-26:])
# Out:
# care_delta_income_2024.csv

# %%
path="/mnt/data/input/care_delta_income_2024.csv"
print(path[-26:-4:])
# Out:
# care_delta_income_2024

# %%
#10. adhaar="123456789012"
   # convert:
      #  XXXX-XXXX-9012

adhaar="123456789012"
print("xxxx-xxxx-"+adhaar[8:])
# Out:
# xxxx-xxxx-9012
