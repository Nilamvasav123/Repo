# %%
nums=[10,20,30,40]
nums.remove(20) 

#[10,30,40]
print(nums)
# Out:
# [10, 30, 40]

# %%
if 5 in nums:
    nums.remove(5)
print(nums)
# Out:
# [10, 30, 40]

# %%
records=["Priyanka","Nilam","Unknown","Amit"]
if "Unknown" in records:
    records.remove("Unknown")
    print(records)
# Out:
# ['Priyanka', 'Nilam', 'Amit']

# %%
nums=[1,2,2,3,2]

while 2 in nums:
    nums.remove(2)
print(nums)
# Out:
# [1, 3]

# %%
nums=[10,20,30]
x=nums.pop() # By default
print(x)
print(nums)
# Out:
# 30
# [10, 20]

# %%
records=["Priyanka","Nilam","NULL","Amit","NULL","NULL","HELLO","NULL"]

while "NULL" in records:
 records.remove("NULL")
 print(records)
# Out:
# ['Priyanka', 'Nilam', 'Amit', 'NULL', 'NULL', 'HELLO', 'NULL']
# ['Priyanka', 'Nilam', 'Amit', 'NULL', 'HELLO', 'NULL']
# ['Priyanka', 'Nilam', 'Amit', 'HELLO', 'NULL']
# ['Priyanka', 'Nilam', 'Amit', 'HELLO']

# %%
status=["SUCESS","FAILED","SUCCESS","FAILED"]

# Remove one failed record maunually 

status.remove("FAILED")
print(status)
# Out:
# ['SUCESS', 'SUCCESS', 'FAILED']

# %%
files=["data.csv","temp.log","report.csv","debug.log"]

for f in files [:]:
    if ".log" in f:
        files.remove(f)
print(files)
# Out:
# ['data.csv', 'report.csv']

# %%
# messages="msg1","msg2","msg3"

messages=["msg1","msg2","msg3"]

latest=messages.pop()
print("Processing:",latest)
# Out:
# Processing: msg3

# %%
records=["Priyanka","Error","Nilam","Error","Amit","Error","Gaurav","Error"]    

# Step 1 - Remove invalid 

while "Error" in records:
    records.remove("Error")

# Step 2 - Process One by one 
proccessed=[]
while records:
    proccessed.append(records.pop())

print(proccessed)

# Step 3 -  # Reset
proccessed.clear()
# Out:
# ['Gaurav', 'Amit', 'Nilam', 'Priyanka']

# %%
proccessed
# Out:
# []

# %%
#Searchig Methods
#index
names=["Priyanka","Rahul","Nilam"]
print(names.index("Rahul"))
# Out:
# 1

# %%
a=[1,2,3]
a.index(3) # ValueError : 5 is not in list
# Out:
# 2

# %%
nums=[10,20,30,20,40]
print(nums.index(20,2)) # Start searching
# Out:
# 3

# %%
nums=[1,2,3,2,3,2]
print(nums.count(2)) # 3
# Out:
# 3

# %%
status=["Sucess","failed","sucess","failed"]
if status.count("Failed") > 0:
    print(" Some records failed")

# %%
status1=["Sucess","failed","sucess","failed"]
if status1.count("Failed") > 0:
    print("Some records failed")

# %%
data = [1, 1, 2, 3, 3, 3]

# Get unique elements
result = set(data)

# Print each element with its count
for i in result:
    print(i, data.count(i))
# Out:
# 1 2
# 2 1
# 3 3

# %%
data =[1,1,2,3,3,3]
result =[]
for i in data:
 if i not in result:
  print(i,data.count(i))
  result.append(i)
# Out:
# 1 2
# 2 1
# 3 3

# %%
#Ordering Methods
nums=[5,2,8,1]
nums.sort()
print(nums)
# Out:
# [1, 2, 5, 8]

# %%
nums=[5,2,8,1]
nums.sort(reverse=True)
print(nums)
# Out:
# [8, 5, 2, 1]

# %%
data=["apple","kiwi","banana"]
data.sort(key=len,reverse=True)

# %%
data
# Out:
# ['banana', 'apple', 'kiwi']

# %%
#refrences
a=[1,2,3]
b=a
b.append(4)

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
print(id(a))
print(id(b))
# Out:
# 2610177293120
# 2610177293120

# %%
##shallow copy

a=[1,2,3]
b=a.copy()

# %%
print(id(a))
print(id(b))
# Out:
# 2610177253888
# 2610177297728

# %%
import copy

a = [[1, 2], [3, 4]]
b = a.copy()   # ensures real  copy

b[0].append(99)        # append to the both inner list
print("a:", a)
print("b:", b)
# Out:
# a: [[1, 2, 99], [3, 4]]
# b: [[1, 2, 99], [3, 4]]

# %%
a=[[1,2],[3,4]]
b=a.copy()
b[0][1]=(99)

# %%
print("a:", a)
print("b:", b)
# Out:
# a: [[1, 99], [3, 4]]
# b: [[1, 99], [3, 4]]

# %%
a=[1,2,3]
b=a.copy()
b[0]=100
print(a) # [1,2,3]
# Out:
# [1, 2, 3]

# %%
a=[[1,2],[3,4]]
b=a.copy()
b[0][0]=100
print(a) # [[100,2],[3,4]]
print(b) # [[100,2],[3,4]]
# Out:
# [[100, 2], [3, 4]]
# [[100, 2], [3, 4]]

# %%
print(id(a),id(b))
print(id(a[0]),id(b[0]))
# Out:
# 2610178562176 2610178936064
# 2610178562304 2610178562304

# %%
#deep copy

import copy 
a=[[1,2],[3,4]]
b=copy.deepcopy(a)

# %%
a
# Out:
# [[1, 2], [3, 4]]

# %%
b
# Out:
# [[1, 2], [3, 4]]

# %%
print(id(a),id(b))
print(id(a[0]),id(b[0]))
# Out:
# 2610178562944 2610178732288
# 2610178578816 2610178731328

# %%
import copy 
a=[[1,2],[3,4]]
b=a
c=copy.deepcopy(a)
b[0][0] =100
print(a) #[[100,2],[3,4]]
print(c) #
# Out:
# [[100, 2], [3, 4]]
# [[1, 2], [3, 4]]

# %%
import copy
a=[10,20,30]
b=copy.deepcopy(a)

print(id(a[0]))
print(id(b[0]))
# Out:
# 140733600724376
# 140733600724376

# %%
a=[1,2,3]
sum(a)
# Out:
# 6

# %%
status=["OK","OK","ERROR"]
print(any(s=="ERROR" for s in status))
# Out:
# True
