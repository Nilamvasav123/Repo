# %%
'''1. Check number is positive or negative 
2. Check number is even or odd 
3. Check gretest of two numbers (Take USer input )'''


#1. Check number is positive or negative

num=int(input("enter num :"))
if num >=0:
    print(f"num is positive {num}")
else :
    print(f"num is negative {num}")
# Out:
# num is negative -10

# %%
num=int(input("enter num :"))
if num%2==0 :
    print(f"number is even {num}")
else :
    print(f"number is odd {num}")
# Out:
# number is odd 7

# %%
#3. Check gretest of two numbers (Take USer input )

num1=int(input("enter num1 : ")) 
num2=int(input("enter num2 : "))

if num1 > num2 :
     print(f"number is greater {num1}")
elif num2 > num1 :
     print(f"number is greater{num2}") 
else:
     print("Both numbers are equal")
# Out:
# Both numbers are equal

# %%
num1, num2 = map(float, input("Enter two numbers separated by space: ").split()) 
if num1 > num2: 
     print(f"{num1} is greater") 
elif num2 > num1: 
      print(f"{num2} is greater") 
else: 
      print ("Both numbers are equal")
# Out:
#   Cell In[16], line 3
#     print(f"{num1} is greater")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %% [markdown]
# 1. Check number is positive
#     if positive, check even and odd
#
# 2. Check age >=18
#     if yes - check driving licence

# %%
num=int(input("enter num :"))
if num > 0:
    print(f"{num} num is positive")
    if num%2==0 :
        print(f"{num} number is even")
    else :
         print(f"{num} number is odd")
else :
       print(f"{num} number is not positive")
# Out:
# 18num is positive
# 18number is even

# %%
'''2. Check age >=18 
    if yes - check driving licence '''

age=int(input("Enter your age: "))
licence = input("Do you have a driving licence? (yes/no): ")

if age>=18 :
    print("you are audult")

    if licence== "yes": 
        print("You can drive") 
    else: 
        print("You need to get a licence")

else :
      print("you are minor")
# Out:
# you are audult
# You need to get a licence

# %%
'''1. Take an integer input 
    - if number is divisible by 3 -> print Divisible by 3 
    - else print - not divisble by 3 '''

num=int(input("enter number :"))
if num%3==0 :
    print(f"{num} num is division by 3 ")
else :
    print(f"{num} num is not division by 3")
# Out:
# 9 num is division by 3

# %%
'''2. Take a number 
    - if number is between 1 to 100 
        - print Even or Odd 
    - else print Out of range '''

num=int(input("enter number :"))

if 1<num<100 :
    print(f"{num} number is 1 to 100 range")
else:
      print(f"{num} out of range")
# Out:
# 60 number is 1 to 100 range

# %%
'''3. input marks
    if marks >=40  - pass 
    else - fail'''

mark=int(input("enter marks:"))
if mark>=40 :
    print(f"{mark} you are pass with good marks")
else:
    print(f"{mark} sorry...yor are fail")
# Out:
# 90 yor are pass with good marks

# %%
'''4. Input age 
    - if age >=60 - Senior citizen discount
    - else - No discount '''

age=int(input("enter age:"))
if age>=60:
    print(f"{age} you are senior citizen you have good discount")
else:
    print(f"{age} hey sorry..you are not senior citizen you don't have discount")
# Out:
# 50 hey sorry..you are not senior citizen you don't have discount

# %%
'''5. Input age and qualification 
    -if age >=18 
        - if qualification is 12th pass -> Eligible 
    - else - Not qualified'''

age=int(input("enter age:"))
qualification=(input("enter qualification:"))
if age>=18 and qualification =='12th pass' :
     print(f"hey your age is {age} and you qulification is {qualification} congratitulation you are eligiable")
else:
     print("you are not eligilible")
# Out:
# hey your age is 20 and you qulification is 12th pass congratitulation you are eligiable

# %%
'''6. Input balance and withrowal amount 
    - if balance > 0 
        - if withrowal <= balance - > Withrowal successful 
        - else "Insufficient balance"
    - Else - Account - Empty '''


bal=int(input("enter amount :"))
wamt=int(input("enter amount :"))
if bal>0 and wamt<= bal :
    print("Withrowal successful")
else:
    print("account empty")
# Out:
# Withrowal successful

# %%
'''7. input salary :
    if salary <= 5L -> No tax
    Else -> " Tax applicable"'''

sal=bal=int(input("enter sal :"))
if sal<=500000:
    print("no tax")
else:
    print("Tax applicable")
# Out:
# Tax applicable

# %%
'''8. Input:
    card inserted(yes/no)
    pin correct (yes/no)
    balance 

    Logic:
        - If card inserted and if pin correct - if balance > 0 -> allow transection 
        - Else - Insufficient Fund 
    - Else - insert card '''

card_inserted=(input("crard inserted (yes/no): "))
pin_correct =(input("pin inserted (yes/no): "))
balance = int(input("enter balance: "))
if card_inserted=='yes'and pin_correct=='yes':
    print("allow transection ")
    if balance>0:
        print("withdrawl amt")
    else:
     print("Insufficient Fund")
else:
      print("insert card")
# Out:
# insert card
