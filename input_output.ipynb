# %% [markdown]
# Questions
# 1. Average of 3 numbers in one line
# 2. Take a name as input and print --> Hello <name>, welcome to python
# 3. Square and Cube - Take a number as input - Number: <n>, square: <n2>, Cube:<n3>
# 4. Take a gae as input and print - You will be <age+1> years old nect year
# 5. Take a salary as input and print salaary after 10% hike
# 6. Take a number and print - Number <n> is Even
# 7. Take marks and print
#     - Rules
#         - >= 75 - Grade A
#         - 60 -74 - Grade B
#         - 35 - 59 Grade C
#         - < 32 - Fail
#
# 8. Take a amount and print:
#     Final amount after discount: <value>
#     Rule:
#         - >= 5000 -> 20% discount
#         - >= 2000 -> 10%
#         - else - No discount

# %%
name="Pari"
age=10
print(name,age)
# Out:
# Pari 10

# %%
print("hello")
print("hi")
# Out:
# hello
# hi

# %%
# Printing values and variable 
x=10
print(x)
# Out:
# 10

# %%
#Print multiple things 
name="nilam"
age=10
print(f"my age is {name} and {age}")

# Why space in betweeen ?
# - Because print() uses a separator parameter call sep.
# sep=" "
# Out:
# my age is nilam and 10

# %%
a=1
b=2
c=3
print(1,2,3,0,20686, sep="#")
print(a,b,c, sep="-")
# Out:
# 1#2#3#0#20686
# 1-2-3

# %%
print("2026","02","02", sep="/")
# Out:
# 2026/02/02

# %%
print("hello", end=" $ ")
print("world")
# Out:
# hello $ world

# %%
# Priniting with formatting 
name="Priya"
age=10
city="pune"
print(f"My name is {name} and age is {age} and my city name is {city}")
# Out:
# My name is Priya and age is 10 and my city name is pune

# %%
a=20
b=10
c=
print(f"Sum is {a+b}")
# Out:
# Sum is 30

# %%
a=10
print(f"Square {a}={a**2}")
# You can put 
# math 
# function cell 
# Conditional
# Out:
# Square 10=100

# %%
pi=3.1415926 ###we using at last f for decimal values
print(f"Pi value {pi:.2f}")
# Out:
# Pi value 3.14

# %%
x=5 ###suppose we need to add  0 infornt of our values.
print (f"{x:04}")
# Out:
# 0005

# %%
print(True) #1
print(False)
# Out:
# True
# False

# %%
name=input("Enter you name: ") # Prompt - The string you pass into input() is just a prompt message 
print(name)
# Out:
# nilam

# %%
age=int(input("Enter age: "))
print(age+1)
# Out:
# 21

# %%
salaray=float(input("Enter your sala. : "))
#print(salaray*1.10) # 
print(f"sal is {(salaray*1.10):.1f}")
# Out:
# sal is 1100.0

# %%
x=input() #"10"
print(x+"5") #105
# Out:
# 105

# %%
a,b=input("Enter a b ").split()
print(a,b)
# Out:
# 1 2

# %%
# Add two numbers 
a= int(input("Enter a: "))
b= int(input("Enter b: "))
print(f"Sum = {a+b}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 2
#       1 # Add two numbers
# ----> 2 a= int(input("Enter a: "))
#       3 b= int(input("Enter b: "))
#       4 print(f"Sum = {a+b}")
#
# ValueError: invalid literal for int() with base 10: '1 2'

# %%
#1. Average of 3 numbers in one line 
a,b,c = map(int, input("Enter a b c ").split())
print(f"avg {(a+b+c)/3}") 

a, b, c = input("Enter 3 numbers: ").split()
print((int(a) + int(b) + int(c)) / 3)

# %%
a, b, c = input("Enter 3 numbers: ").split()
print((int(a) + int(b) + int(c)) / 3)
# Out:
# 10.0

# %%
a= int(input("Enter value for A:"))
b= int(input("Enter value for B:"))
c= int(input("Enter value for C:"))
print(f"Average ={a+b+c/3}")
# Out:
# Average =23.333333333333332

# %%
#2. Take a name as input and print --> Hello <name>, welcome to python
Name="nilam"
print(f"hello {Name} welcome to python")
# Out:
# hello nilam welcome to python

# %%
nm=input("enter nm :")
print(f" hello {nm}, welcome to python")
# Out:
#  hell nilima, welcome to python

# %%
#3. Square and Cube - Take a number as input - Number: <n>, square: <n2>, Cube:<n3>
a=10
b=20
print(f"Square {a}={a**2}")
print(f"cube {b}={b**3}")
# Out:
# Square 10=100
# cube 20=8000

# %%
sq=int(input("enter sq :"))
print(f"Number :{a},Square :{sq}={sq**2},cube {sq}={sq**3}")
# Out:
# Number :10,Square :10=100,cube 10=1000

# %%
a= int(input("Enter number:"))
print(f"Number :{a},square: {a*2},Cube: {a*3}")
# Out:
# Number :10,square: 20,Cube: 30

# %%
#4. Take a gae as input and print - You will be <age+1> years old nect year
age=20
print(f"{age+1}")
# Out:
# 21

# %%
age=int(input("enter age:"))
print(f"you will be {age+1} years old next year")
# Out:
# you will be 31 years old next year

# %%
#5. Take a salary as input and print salaary after 10% hike 
salary=float(input("mysalry is: "))
print(f"sal is {(salary*1.10):.2f}")
# Out:
# sal is 1100.00

# %%
#6. Take a number and print - Number <n> is Even 
even1=int(input("Enter number:"))
#print(f"Number {even1} is", ["Even", "Odd"][even1 % 2])
print(f"Number {even1} is Even", [even1%2==0])
# Out:
# Number 2 is Even [True]

# %%
#7. Take marks and print 
 #   - Rules 
  #      - >= 75 - Grade A 
   #     - 60 -74 - Grade B
    ##   - < 32 - Fail 


mk=int(input("enter nm: "))
print(f"grade A,{mk>=75}\n grade B {60<mk<74}\n fail {mk<32}")
# Out:
# grade A,False
#  grade B True
#  fail False

# %%
 #Take a amount and print: 
  #  Final amount after discount: <value>
   # Rule:
    #    - >= 5000 -> 20% discount 
     #   - >= 2000 -> 10% 
      #  - else - No discount

amt = float(input("Enter amount: "))
discount = (amt >= 5000) * 20 + (amt >= 2000 and amt < 5000) * 10
final_amt = amt - (amt * discount / 100)
print(f"Final amount after discount: {final_amt}")
# Out:
# Final amount after discount: 2700.0
